# %%
import numpy as np
from plot_experiments_together import plot_experiments_together
from plot_experiments_together_average_rois import plot_experiments_together_average_rois

# %% [markdown]
# ## Figure 3: nonlinguistic conditions

# %%
title = 'NONLING_FIGURE'
result_versions = [
    'mROI_0.1_*LOC_GSS_percentile-ROI-level_0.2_0.1',
    'mROI_0.2_*LOC_GSS_percentile-ROI-level_0.2_0.1',
    'mROI_0.1_*LOC_GSS_percentile-whole-brain_0.1_0.1',
    'mROI_0.2_*LOC_GSS_percentile-whole-brain_0.1_0.1',
    'mROI_0.1_*LOC_language_GSS_percentile-whole-brain_0.1_0.1',
    'mROI_0.2_*LOC_language_GSS_percentile-whole-brain_0.1_0.1',
    'mROI_0.1_*LOC_language_standard',
    'mROI_0.2_*LOC_language_standard',
    'mROI_0.1_*LOC_symmetrical_GSS_percentile-whole-brain_0.1_0.1',
    'mROI_0.2_*LOC_symmetrical_GSS_percentile-whole-brain_0.1_0.1'
]
experiments = [
    'langloc',
    'ArticLoc',
    # 'ProdLoc',
    'Math_2015onward_AliceLocalizer',
    'MDloc_atlas',
    'DigSpan',
    'MSIT',
    'vMSIT',
    'vstroopBL',
    'Music_2009',
    'Music_2019',
    'DyLoc_Pritchett2018',
    'Cloudy_Shain2023',
    ['EventsRev',
     'EventsOrig',
     'events2move'],
]
conditions = [
    ['S','N'],
    ['P','T'],
    # ['NProd'],
    ['H','E'],
    ['H','E'],
    ['H','E'],
    ['H','E'],
    ['H','E'],
    ['H','E'],
    ['I','B'],
    ['MUS_ORCH','MUS_SOLO','MUS_DR','ANIM','ENV_A'],
    ['Faces','Bodies','Scenes','Objects','ScrObjects'],
    ['Mental','Physical','Social','Pain'],
    ['Pic_Sem','Pic_Perc'], # 'Sent_Sem','Sent_Perc',
]
colors = [
        np.array([[0.15,0.15,0.15],
                  [0.75,0.75,0.75]]),
        np.array(['#541E2C',
                  '#541E2C']),
        # np.array(['#FFE3E1']),
        np.array(['#FF011F',
                  '#FF011F']),
        np.array(['#0000FE',
                   '#0000FE']),
        np.array(['#00C200',
                  '#00C200']),
        np.array(['#FFFF1D',
                   '#FFFF1D']),
        np.array(['#FFCA2B',
                   '#FFCA2B']), 
        np.array(['#FF821F',
                   '#FF821F']),
        np.array(['#FF0084',
                   '#FF0084']),
        np.array(['#5D69B4',
                   '#677FA3',
                   '#5C8FAD',
                   '#55915D',
                   '#A0CE9F']),
        np.array(['#EA88C6',
                   '#72DDE1',
                   '#78DD00',
                   '#E99000',
                   '#E9DB37']),
        np.array(['#8B7192',
                   '#B399C7',
                   '#C4A7D8',
                   '#D2BEE7']),
        np.array(['#343FB6',
                   '#C0C0FF']), # '#B0453B','#F5ACAC',
]
# colors = [
#         np.array([[0.15,0.15,0.15],
#                   [0.75,0.75,0.75]]),
#         np.array([(1.0, 0.5215686274509804, 0.0, 1.0),
#                   (1.0, 0.5215686274509804, 0.0, 0.2)]),
#         np.array([(0.35294117647058826, 0.09411764705882353, 0.6039215686274509, 1.0),
#                   (0.35294117647058826, 0.09411764705882353, 0.6039215686274509, 0.2),]),
#         np.array([(0.35294117647058826, 0.09411764705882353, 0.6039215686274509, 0.93),
#                   (0.35294117647058826, 0.09411764705882353, 0.6039215686274509, 0.2),]),
#         np.array([(0.35294117647058826, 0.09411764705882353, 0.6039215686274509, 0.86),
#                   (0.35294117647058826, 0.09411764705882353, 0.6039215686274509, 0.2),]),
#         np.array([(0.35294117647058826, 0.09411764705882353, 0.6039215686274509, 0.79),
#                   (0.35294117647058826, 0.09411764705882353, 0.6039215686274509, 0.2),]),
#         np.array([(0.35294117647058826, 0.09411764705882353, 0.6039215686274509, 0.72),
#                   (0.35294117647058826, 0.09411764705882353, 0.6039215686274509, 0.2),]),
#         np.array([(0.35294117647058826, 0.09411764705882353, 0.6039215686274509, 0.65),
#                   (0.35294117647058826, 0.09411764705882353, 0.6039215686274509, 0.2),]),
#         np.array([(0.12549019607843137, 0.5450980392156862, 0.22745098039215686, 1.0),
#                   (0.12549019607843137, 0.5450980392156862, 0.22745098039215686, 0.2)]),
#         np.array([(0.12549019607843137, 0.5450980392156862, 0.22745098039215686, 0.9),
#                   (0.12549019607843137, 0.5450980392156862, 0.22745098039215686, 0.8),
#                   (0.12549019607843137, 0.5450980392156862, 0.22745098039215686, 0.7),
#                   (0.12549019607843137, 0.5450980392156862, 0.22745098039215686, 0.2),
#                   (0.12549019607843137, 0.5450980392156862, 0.22745098039215686, 0.2)]),
#         np.array([(0.00392156862745098, 0.592156862745098, 0.9647058823529412, 1.0),
#                   (0.00392156862745098, 0.592156862745098, 0.9647058823529412, 0.9),
#                   (0.00392156862745098, 0.592156862745098, 0.9647058823529412, 0.2),
#                   (0.00392156862745098, 0.592156862745098, 0.9647058823529412, 0.2),
#                   (0.00392156862745098, 0.592156862745098, 0.9647058823529412, 0.2)]),
#         np.array([(0.03529411764705882, 0.047058823529411764, 0.6078431372549019, 1.0),
#                   (0.03529411764705882, 0.047058823529411764, 0.6078431372549019, 0.9),
#                   (0.03529411764705882, 0.047058823529411764, 0.6078431372549019, 0.8),
#                   (0.03529411764705882, 0.047058823529411764, 0.6078431372549019, 0.7)]),
#         np.array([(0.26666666666666666, 0.8117647058823529, 0.796078431372549, 1.0),
#                   (0.26666666666666666, 0.8117647058823529, 0.796078431372549, 0.2)]), # '#343FB6','#C0C0FF'
# ]

# %%
# all data points, NO scatter plot
test = plot_experiments_together(result_versions,experiments,conditions,colors,title,no_outliers=False,set_ylim=False,include_scatter=False)
# Out:
# mROI_0.1_*LOC_GSS_percentile-ROI-level_0.2_0.1:
# -----------------------------------------------
# ROI 1: Right_CrusII_VIIb_VIIIa
# langloc/data/mROI_0.1_langLOC_langEFFECT_GSS_percentile-ROI-level_0.2_0.1.csv
#   Number of subjects (by condition):  [754. 754.]
# ArticLoc/data/mROI_0.1_ArticLocEFFECT_langLOC_GSS_percentile-ROI-level_0.2_0.1.csv
#   Number of subjects (by condition):  [33. 33.]
# Math_2015onward_AliceLocalizer/data/mROI_0.1_Math2015EFFECT_langLOC_GSS_percentile-ROI-level_0.2_0.1.csv
#   Number of subjects (by condition):  [75. 75.]
# MDloc_atlas/data/mROI_0.1_MDatlasEFFECT_langLOC_GSS_percentile-ROI-level_0.2_0.1.csv
#   Number of subjects (by condition):  [640. 640.]
# DigSpan/data/mROI_0.1_DigSpanEFFECT_langLOC_GSS_percentile-ROI-level_0.2_0.1.csv
#   Number of subjects (by condition):  [19. 19.]
# MSIT/data/mROI_0.1_MSITEFFECT_langLOC_GSS_percentile-ROI-level_0.2_0.1.csv
#   Number of subjects (by condition):  [15. 15.]
# ...

# %%
# all data points, NO scatter plot, averaged over LH lang regions
result_versionsL = ['mROI_0.1_*LOC_language_standard']
rois_to_average = ['LH_IFGorb','LH_IFG','LH_MFG','LH_AntTemp','LH_PostTemp']
plot_experiments_together_average_rois(result_versionsL,
                                       experiments,
                                       conditions,
                                       colors,
                                       title,
                                       no_outliers=False,
                                       set_ylim=False,
                                       rois_to_average=rois_to_average,
                                       roi_group_name='LH_lang',
                                       include_scatter=False)
# Out:
# mROI_0.1_*LOC_language_standard:
# --------------------------------
# langloc/data/mROI_0.1_langLOC_langEFFECT_language_standard.csv
# ROI 1: LH_IFGorb
# ROI 2: LH_IFG
# ROI 3: LH_MFG
# ROI 4: LH_AntTemp
# ROI 5: LH_PostTemp
#   Number of subjects (by condition):  [754. 754.]
# ArticLoc/data/mROI_0.1_ArticLocEFFECT_langLOC_language_standard.csv
# ROI 1: LH_IFGorb
# ROI 2: LH_IFG
# ROI 3: LH_MFG
# ROI 4: LH_AntTemp
# ROI 5: LH_PostTemp
#   Number of subjects (by condition):  [33. 33.]
# Math_2015onward_AliceLocalizer/data/mROI_0.1_Math2015EFFECT_langLOC_language_standard.csv
# ROI 1: LH_IFGorb
# ROI 2: LH_IFG
# ROI 3: LH_MFG
# ROI 4: LH_AntTemp
# ROI 5: LH_PostTemp
#   Number of subjects (by condition):  [75. 75.]
# MDloc_atlas/data/mROI_0.1_MDatlasEFFECT_langLOC_language_standard.csv
# ROI 1: LH_IFGorb
# ROI 2: LH_IFG
# ROI 3: LH_MFG
# ROI 4: LH_AntTemp
# ROI 5: LH_PostTemp
#   Number of subjects (by condition):  [640. 640.]
# ...

# %%
# all data points, NO scatter plot, TRIMMED y-axes limits (for GSS_percentile-whole-brain_0.1_0.1 parcels)
result_versions = ['mROI_0.1_*LOC_GSS_percentile-whole-brain_0.1_0.1']
ylims = [
    [-0.35,0.75], # by ROIs
    [-0.25,1],
    [-0.25,1.25],
    [-0.25,1.75]
]
plot_experiments_together(result_versions,experiments,conditions,colors,title,no_outliers=False,set_ylim=True,ylim=ylims,include_scatter=False)
# Out:
# mROI_0.1_*LOC_GSS_percentile-whole-brain_0.1_0.1:
# -------------------------------------------------
# ROI 1: Right_CrusII_VIIb
# langloc/data/mROI_0.1_langLOC_langEFFECT_GSS_percentile-whole-brain_0.1_0.1.csv
#   Number of subjects (by condition):  [754. 754.]
# ArticLoc/data/mROI_0.1_ArticLocEFFECT_langLOC_GSS_percentile-whole-brain_0.1_0.1.csv
#   Number of subjects (by condition):  [33. 33.]
# ProdLoc/data/mROI_0.1_ProdEFFECT_langLOC_GSS_percentile-whole-brain_0.1_0.1.csv
#   Number of subjects (by condition):  [27.]
# Math_2015onward_AliceLocalizer/data/mROI_0.1_Math2015EFFECT_langLOC_GSS_percentile-whole-brain_0.1_0.1.csv
#   Number of subjects (by condition):  [75. 75.]
# MDloc_atlas/data/mROI_0.1_MDatlasEFFECT_langLOC_GSS_percentile-whole-brain_0.1_0.1.csv
#   Number of subjects (by condition):  [640. 640.]
# DigSpan/data/mROI_0.1_DigSpanEFFECT_langLOC_GSS_percentile-whole-brain_0.1_0.1.csv
#   Number of subjects (by condition):  [19. 19.]
# ...

# %%
# all data points, WITH scatter plot
plot_experiments_together(result_versions,experiments,conditions,colors,title,no_outliers=False,set_ylim=False)
# Out:
# mROI_0.1_*LOC_GSS_percentile-ROI-level_0.2_0.1:
# -----------------------------------------------
# ROI 1: Right_CrusII_VIIb_VIIIa
# langloc/data/mROI_0.1_langLOC_langEFFECT_GSS_percentile-ROI-level_0.2_0.1.csv
#   Number of subjects (by condition):  [754. 754.]
# ArticLoc/data/mROI_0.1_ArticLocEFFECT_langLOC_GSS_percentile-ROI-level_0.2_0.1.csv
#   Number of subjects (by condition):  [33. 33.]
# Math_2015onward_AliceLocalizer/data/mROI_0.1_Math2015EFFECT_langLOC_GSS_percentile-ROI-level_0.2_0.1.csv
#   Number of subjects (by condition):  [75. 75.]
# MDloc_atlas/data/mROI_0.1_MDatlasEFFECT_langLOC_GSS_percentile-ROI-level_0.2_0.1.csv
#   Number of subjects (by condition):  [640. 640.]
# DigSpan/data/mROI_0.1_DigSpanEFFECT_langLOC_GSS_percentile-ROI-level_0.2_0.1.csv
#   Number of subjects (by condition):  [19. 19.]
# MSIT/data/mROI_0.1_MSITEFFECT_langLOC_GSS_percentile-ROI-level_0.2_0.1.csv
#   Number of subjects (by condition):  [15. 15.]
# ...

# %%
# all data points, WITH scatter plot, averaged over LH lang regions
result_versionsL = ['mROI_0.1_*LOC_language_standard']
rois_to_average = ['LH_IFGorb','LH_IFG','LH_MFG','LH_AntTemp','LH_PostTemp']
plot_experiments_together_average_rois(result_versionsL,
                                       experiments,
                                       conditions,
                                       colors,
                                       title,
                                       no_outliers=False,
                                       set_ylim=False,
                                       rois_to_average=rois_to_average,
                                       roi_group_name='LH_lang')
# Out:
# mROI_0.1_*LOC_language_standard:
# --------------------------------
# langloc/data/mROI_0.1_langLOC_langEFFECT_language_standard.csv
# ROI 1: LH_IFGorb
# ROI 2: LH_IFG
# ROI 3: LH_MFG
# ROI 4: LH_AntTemp
# ROI 5: LH_PostTemp
#   Number of subjects (by condition):  [754. 754.]
# ArticLoc/data/mROI_0.1_ArticLocEFFECT_langLOC_language_standard.csv
# ROI 1: LH_IFGorb
# ROI 2: LH_IFG
# ROI 3: LH_MFG
# ROI 4: LH_AntTemp
# ROI 5: LH_PostTemp
#   Number of subjects (by condition):  [33. 33.]
# Math_2015onward_AliceLocalizer/data/mROI_0.1_Math2015EFFECT_langLOC_language_standard.csv
# ROI 1: LH_IFGorb
# ROI 2: LH_IFG
# ROI 3: LH_MFG
# ROI 4: LH_AntTemp
# ROI 5: LH_PostTemp
#   Number of subjects (by condition):  [75. 75.]
# MDloc_atlas/data/mROI_0.1_MDatlasEFFECT_langLOC_language_standard.csv
# ROI 1: LH_IFGorb
# ROI 2: LH_IFG
# ROI 3: LH_MFG
# ROI 4: LH_AntTemp
# ROI 5: LH_PostTemp
#   Number of subjects (by condition):  [640. 640.]
# ...

# %%
# all data points, WITH scatter plot, TRIMMED y-axes limits (for GSS_percentile-whole-brain_0.1_0.1 parcels)
result_versionsT = ['mROI_0.1_*LOC_GSS_percentile-whole-brain_0.1_0.1']
ylims = [
    [-2,2.5], # by ROIs
    [-2.2,5.5],
    [-1.5,4],
    [-2.8,6]
]
plot_experiments_together(result_versionsT,experiments,conditions,colors,title,no_outliers=False,set_ylim=True,ylim=ylims)
# Out:
# mROI_0.1_*LOC_GSS_percentile-whole-brain_0.1_0.1:
# -------------------------------------------------
# ROI 1: Right_CrusII_VIIb
# langloc/data/mROI_0.1_langLOC_langEFFECT_GSS_percentile-whole-brain_0.1_0.1.csv
#   Number of subjects (by condition):  [754. 754.]
# ArticLoc/data/mROI_0.1_ArticLocEFFECT_langLOC_GSS_percentile-whole-brain_0.1_0.1.csv
#   Number of subjects (by condition):  [33. 33.]
# Math_2015onward_AliceLocalizer/data/mROI_0.1_Math2015EFFECT_langLOC_GSS_percentile-whole-brain_0.1_0.1.csv
#   Number of subjects (by condition):  [75. 75.]
# MDloc_atlas/data/mROI_0.1_MDatlasEFFECT_langLOC_GSS_percentile-whole-brain_0.1_0.1.csv
#   Number of subjects (by condition):  [640. 640.]
# DigSpan/data/mROI_0.1_DigSpanEFFECT_langLOC_GSS_percentile-whole-brain_0.1_0.1.csv
#   Number of subjects (by condition):  [19. 19.]
# MSIT/data/mROI_0.1_MSITEFFECT_langLOC_GSS_percentile-whole-brain_0.1_0.1.csv
#   Number of subjects (by condition):  [15. 15.]
# ...

# %% [markdown]
# ## Figure 4: linguistic conditions

# %%
title = 'LING_COMP_PROD_FIGURE'
result_versions = [
    'mROI_0.1_*LOC_GSS_percentile-ROI-level_0.2_0.1',
    'mROI_0.2_*LOC_GSS_percentile-ROI-level_0.2_0.1',
    'mROI_0.1_*LOC_GSS_percentile-whole-brain_0.1_0.1',
    'mROI_0.2_*LOC_GSS_percentile-whole-brain_0.1_0.1',
    'mROI_0.1_*LOC_language_GSS_percentile-whole-brain_0.1_0.1',
    'mROI_0.2_*LOC_language_GSS_percentile-whole-brain_0.1_0.1',
    'mROI_0.1_*LOC_language_standard',
    'mROI_0.2_*LOC_language_standard',
    'mROI_0.1_*LOC_symmetrical_GSS_percentile-whole-brain_0.1_0.1',
    'mROI_0.2_*LOC_symmetrical_GSS_percentile-whole-brain_0.1_0.1'
]
experiments = [
    ['SWJNV2',
     'Nlength_con2',
     'SWJN_deluxe'],
    'ProdLoc',
    'ProdLoc_typing',
]
conditions = [
    ['S','W','J','N'],
    ['SProd','WProd','NProd'],
    ['SProd','WProd','NProd']
]
colors = [
    np.array([[0.15,0.15,0.15],
               [0.35,0.35,0.35],
               [0.55,0.55,0.55],
               [0.75,0.75,0.75]]),
    ['#B22223',
     '#EE8080',
     '#FFE3E1'],
    ['#B22223',
     '#EE8080',
     '#FFE3E1']
]

# %%
# all data points, NO scatter plot
test = plot_experiments_together(result_versions,experiments,conditions,colors,title,no_outliers=False,set_ylim=False,include_scatter=False)
# Out:
# mROI_0.1_*LOC_GSS_percentile-ROI-level_0.2_0.1:
# -----------------------------------------------
# ROI 1: Right_CrusII_VIIb_VIIIa
# SWJNV2/data/mROI_0.1_SWJNEFFECT_langLOC_GSS_percentile-ROI-level_0.2_0.1.csv
# Nlength_con2/data/mROI_0.1_NlengthEFFECT_langLOC_GSS_percentile-ROI-level_0.2_0.1.csv
# SWJN_deluxe/data/mROI_0.1_SWJNDeluxeEFFECT_langLOC_GSS_percentile-ROI-level_0.2_0.1.csv
#   Number of subjects (by condition):  [71. 71. 71. 71.]
# ProdLoc/data/mROI_0.1_ProdEFFECT_langLOC_GSS_percentile-ROI-level_0.2_0.1.csv
#   Number of subjects (by condition):  [27. 27. 27.]
# ProdLoc_typing/data/mROI_0.1_ProdTypingEFFECT_langLOC_GSS_percentile-ROI-level_0.2_0.1.csv
#   Number of subjects (by condition):  [13. 13. 13.]
# ROI 2: Right_VI_CrusI_CrusII_Dentate
# SWJNV2/data/mROI_0.1_SWJNEFFECT_langLOC_GSS_percentile-ROI-level_0.2_0.1.csv
# Nlength_con2/data/mROI_0.1_NlengthEFFECT_langLOC_GSS_percentile-ROI-level_0.2_0.1.csv
# ...

# %%
# all data points, NO scatter plot, averaged over LH lang regions
result_versionsL = ['mROI_0.1_*LOC_language_standard']
rois_to_average = ['LH_IFGorb','LH_IFG','LH_MFG','LH_AntTemp','LH_PostTemp']
plot_experiments_together_average_rois(result_versionsL,
                                       experiments,
                                       conditions,
                                       colors,
                                       title,
                                       no_outliers=False,
                                       set_ylim=False,
                                       rois_to_average=rois_to_average,
                                       roi_group_name='LH_lang',
                                       include_scatter=False)
# Out:
# mROI_0.1_*LOC_language_standard:
# --------------------------------
# SWJNV2/data/mROI_0.1_SWJNEFFECT_langLOC_language_standard.csv
# Nlength_con2/data/mROI_0.1_NlengthEFFECT_langLOC_language_standard.csv
# SWJN_deluxe/data/mROI_0.1_SWJNDeluxeEFFECT_langLOC_language_standard.csv
# ROI 1: LH_IFGorb
# ROI 2: LH_IFG
# ROI 3: LH_MFG
# ROI 4: LH_AntTemp
# ROI 5: LH_PostTemp
#   Number of subjects (by condition):  [71. 71. 71. 71.]
# ProdLoc/data/mROI_0.1_ProdEFFECT_langLOC_language_standard.csv
# ROI 1: LH_IFGorb
# ROI 2: LH_IFG
# ROI 3: LH_MFG
# ROI 4: LH_AntTemp
# ROI 5: LH_PostTemp
#   Number of subjects (by condition):  [27. 27. 27.]
# ProdLoc_typing/data/mROI_0.1_ProdTypingEFFECT_langLOC_language_standard.csv
# ROI 1: LH_IFGorb
# ROI 2: LH_IFG
# ROI 3: LH_MFG
# ROI 4: LH_AntTemp
# ROI 5: LH_PostTemp
#   Number of subjects (by condition):  [13. 13. 13.]

# %%
# all data points, NO scatter plot, TRIMMED y-axes limits (for GSS_percentile-whole-brain_0.1_0.1 parcels)
result_versions = ['mROI_0.1_*LOC_GSS_percentile-whole-brain_0.1_0.1']
ylims = [
    [-0.35,0.75], # by ROIs
    [-0.25,1],
    [-0.25,1.25],
    [-0.25,1.75]
]
plot_experiments_together(result_versions,experiments,conditions,colors,title,no_outliers=False,set_ylim=True,ylim=ylims,include_scatter=False)
# Out:
# mROI_0.1_*LOC_GSS_percentile-whole-brain_0.1_0.1:
# -------------------------------------------------
# ROI 1: Right_CrusII_VIIb
# langloc/data/mROI_0.1_langLOC_langEFFECT_GSS_percentile-whole-brain_0.1_0.1.csv
#   Number of subjects (by condition):  [754. 754.]
# ArticLoc/data/mROI_0.1_ArticLocEFFECT_langLOC_GSS_percentile-whole-brain_0.1_0.1.csv
#   Number of subjects (by condition):  [33. 33.]
# ProdLoc/data/mROI_0.1_ProdEFFECT_langLOC_GSS_percentile-whole-brain_0.1_0.1.csv
#   Number of subjects (by condition):  [27.]
# Math_2015onward_AliceLocalizer/data/mROI_0.1_Math2015EFFECT_langLOC_GSS_percentile-whole-brain_0.1_0.1.csv
#   Number of subjects (by condition):  [75. 75.]
# MDloc_atlas/data/mROI_0.1_MDatlasEFFECT_langLOC_GSS_percentile-whole-brain_0.1_0.1.csv
#   Number of subjects (by condition):  [640. 640.]
# DigSpan/data/mROI_0.1_DigSpanEFFECT_langLOC_GSS_percentile-whole-brain_0.1_0.1.csv
#   Number of subjects (by condition):  [19. 19.]
# ...

# %%
# all data points, WITH scatter plot
plot_experiments_together(result_versions,experiments,conditions,colors,title,no_outliers=False,set_ylim=False)
# Out:
# mROI_0.1_*LOC_GSS_percentile-ROI-level_0.2_0.1:
# -----------------------------------------------
# ROI 1: Right_CrusII_VIIb_VIIIa
# SWJNV2/data/mROI_0.1_SWJNEFFECT_langLOC_GSS_percentile-ROI-level_0.2_0.1.csv
# Nlength_con2/data/mROI_0.1_NlengthEFFECT_langLOC_GSS_percentile-ROI-level_0.2_0.1.csv
# SWJN_deluxe/data/mROI_0.1_SWJNDeluxeEFFECT_langLOC_GSS_percentile-ROI-level_0.2_0.1.csv
#   Number of subjects (by condition):  [71. 71. 71. 71.]
# ProdLoc/data/mROI_0.1_ProdEFFECT_langLOC_GSS_percentile-ROI-level_0.2_0.1.csv
#   Number of subjects (by condition):  [27. 27. 27.]
# ProdLoc_typing/data/mROI_0.1_ProdTypingEFFECT_langLOC_GSS_percentile-ROI-level_0.2_0.1.csv
#   Number of subjects (by condition):  [13. 13. 13.]
# ROI 2: Right_VI_CrusI_CrusII_Dentate
# SWJNV2/data/mROI_0.1_SWJNEFFECT_langLOC_GSS_percentile-ROI-level_0.2_0.1.csv
# Nlength_con2/data/mROI_0.1_NlengthEFFECT_langLOC_GSS_percentile-ROI-level_0.2_0.1.csv
# ...

# %%
# all data points, WITH scatter plot, averaged over LH lang regions
result_versionsL = ['mROI_0.1_*LOC_language_standard']
rois_to_average = ['LH_IFGorb','LH_IFG','LH_MFG','LH_AntTemp','LH_PostTemp']
plot_experiments_together_average_rois(result_versionsL,
                                       experiments,
                                       conditions,
                                       colors,
                                       title,
                                       no_outliers=False,
                                       set_ylim=False,
                                       rois_to_average=rois_to_average,
                                       roi_group_name='LH_lang')
# Out:
# mROI_0.1_*LOC_language_standard:
# --------------------------------
# SWJNV2/data/mROI_0.1_SWJNEFFECT_langLOC_language_standard.csv
# Nlength_con2/data/mROI_0.1_NlengthEFFECT_langLOC_language_standard.csv
# SWJN_deluxe/data/mROI_0.1_SWJNDeluxeEFFECT_langLOC_language_standard.csv
# ROI 1: LH_IFGorb
# ROI 2: LH_IFG
# ROI 3: LH_MFG
# ROI 4: LH_AntTemp
# ROI 5: LH_PostTemp
#   Number of subjects (by condition):  [71. 71. 71. 71.]
# ProdLoc/data/mROI_0.1_ProdEFFECT_langLOC_language_standard.csv
# ROI 1: LH_IFGorb
# ROI 2: LH_IFG
# ROI 3: LH_MFG
# ROI 4: LH_AntTemp
# ROI 5: LH_PostTemp
#   Number of subjects (by condition):  [27. 27. 27.]
# ProdLoc_typing/data/mROI_0.1_ProdTypingEFFECT_langLOC_language_standard.csv
# ROI 1: LH_IFGorb
# ROI 2: LH_IFG
# ROI 3: LH_MFG
# ROI 4: LH_AntTemp
# ROI 5: LH_PostTemp
#   Number of subjects (by condition):  [13. 13. 13.]

# %%
# all data points, WITH scatter plot, TRIMMED y-axes limits (for GSS_percentile-whole-brain_0.1_0.1 parcels)
result_versions = ['mROI_0.1_*LOC_GSS_percentile-whole-brain_0.1_0.1']
ylims = [
    [-2,2.5], # by ROIs
    [-2.2,5.5],
    [-1.5,4],
    [-2.8,6]
]
plot_experiments_together(result_versions,experiments,conditions,colors,title,no_outliers=False,set_ylim=True,ylim=ylims)
# Out:
# mROI_0.1_*LOC_GSS_percentile-whole-brain_0.1_0.1:
# -------------------------------------------------
# ROI 1: Right_CrusII_VIIb
# langloc/data/mROI_0.1_langLOC_langEFFECT_GSS_percentile-whole-brain_0.1_0.1.csv
#   Number of subjects (by condition):  [754. 754.]
# ArticLoc/data/mROI_0.1_ArticLocEFFECT_langLOC_GSS_percentile-whole-brain_0.1_0.1.csv
#   Number of subjects (by condition):  [33. 33.]
# Math_2015onward_AliceLocalizer/data/mROI_0.1_Math2015EFFECT_langLOC_GSS_percentile-whole-brain_0.1_0.1.csv
#   Number of subjects (by condition):  [75. 75.]
# MDloc_atlas/data/mROI_0.1_MDatlasEFFECT_langLOC_GSS_percentile-whole-brain_0.1_0.1.csv
#   Number of subjects (by condition):  [640. 640.]
# DigSpan/data/mROI_0.1_DigSpanEFFECT_langLOC_GSS_percentile-whole-brain_0.1_0.1.csv
#   Number of subjects (by condition):  [19. 19.]
# MSIT/data/mROI_0.1_MSITEFFECT_langLOC_GSS_percentile-whole-brain_0.1_0.1.csv
#   Number of subjects (by condition):  [15. 15.]
# ...

# %% [markdown]
# ## Figure S6: all semantic experiments separately (n=3)

# %%
title = 'SEMANTIC_ALL_SFIGURE'
result_versions = [
    'mROI_0.1_*LOC_GSS_percentile-ROI-level_0.2_0.1',
    'mROI_0.2_*LOC_GSS_percentile-ROI-level_0.2_0.1',
    'mROI_0.1_*LOC_GSS_percentile-whole-brain_0.1_0.1',
    'mROI_0.2_*LOC_GSS_percentile-whole-brain_0.1_0.1',
    'mROI_0.1_*LOC_language_GSS_percentile-whole-brain_0.1_0.1',
    'mROI_0.2_*LOC_language_GSS_percentile-whole-brain_0.1_0.1',
    'mROI_0.1_*LOC_language_standard',
    'mROI_0.2_*LOC_language_standard',
    'mROI_0.1_*LOC_symmetrical_GSS_percentile-whole-brain_0.1_0.1',
    'mROI_0.2_*LOC_symmetrical_GSS_percentile-whole-brain_0.1_0.1'
]
experiments = [
    'EventsRev',
    'EventsOrig',
    'events2move',
]
conditions = [
    ['Sent_Sem','Sent_Perc','Pic_Sem','Pic_Perc'],
    ['Sent_Sem','Sent_Perc','Pic_Sem','Pic_Perc'],
    ['Sent_Sem','Sent_Perc','Pic_Sem','Pic_Perc']
]
# colors = [
#         np.array(['#B0453B',
#                    '#F5ACAC',
#                    '#343FB6',
#                    '#C0C0FF']),
#         np.array(['#B0453B',
#                    '#F5ACAC',
#                    '#343FB6',
#                    '#C0C0FF']),
#         np.array(['#B0453B',
#                    '#F5ACAC',
#                    '#343FB6',
#                    '#C0C0FF'])
# ]
colors = [
        np.array([(0.15, 0.15, 0.15, 1.0),
                  (0.15, 0.15, 0.15, 0.1),
                  (0.26666666666666666, 0.8117647058823529, 0.796078431372549, 1.0),
                  (0.26666666666666666, 0.8117647058823529, 0.796078431372549, 0.2)]),
        np.array([(0.15, 0.15, 0.15, 1.0),
                  (0.15, 0.15, 0.15, 0.1),
                  (0.26666666666666666, 0.8117647058823529, 0.796078431372549, 1.0),
                  (0.26666666666666666, 0.8117647058823529, 0.796078431372549, 0.2)]),
        np.array([(0.15, 0.15, 0.15, 1.0),
                  (0.15, 0.15, 0.15, 0.1),
                  (0.26666666666666666, 0.8117647058823529, 0.796078431372549, 1.0),
                  (0.26666666666666666, 0.8117647058823529, 0.796078431372549, 0.2)]),
]

# %%
# all data points, NO scatter plot
test = plot_experiments_together(result_versions,experiments,conditions,colors,title,no_outliers=False,set_ylim=False,include_scatter=False)
# Out:
# mROI_0.1_*LOC_GSS_percentile-ROI-level_0.2_0.1:
# -----------------------------------------------
# ROI 1: Right_CrusII_VIIb_VIIIa
# EventsRev/data/mROI_0.1_EventsRevEFFECT_langLOC_GSS_percentile-ROI-level_0.2_0.1.csv
#   Number of subjects (by condition):  [19. 19. 19. 19.]
# EventsOrig/data/mROI_0.1_EventsOrigEFFECT_langLOC_GSS_percentile-ROI-level_0.2_0.1.csv
#   Number of subjects (by condition):  [12. 12. 12. 12.]
# events2move/data/mROI_0.1_events2moveEFFECT_langLOC_GSS_percentile-ROI-level_0.2_0.1.csv
#   Number of subjects (by condition):  [14. 14. 14. 14.]
# ROI 2: Right_VI_CrusI_CrusII_Dentate
# EventsRev/data/mROI_0.1_EventsRevEFFECT_langLOC_GSS_percentile-ROI-level_0.2_0.1.csv
#   Number of subjects (by condition):  [19. 19. 19. 19.]
# EventsOrig/data/mROI_0.1_EventsOrigEFFECT_langLOC_GSS_percentile-ROI-level_0.2_0.1.csv
#   Number of subjects (by condition):  [12. 12. 12. 12.]
# events2move/data/mROI_0.1_events2moveEFFECT_langLOC_GSS_percentile-ROI-level_0.2_0.1.csv
# ...

# %%
# all data points, NO scatter plot, averaged over LH lang regions
result_versionsL = ['mROI_0.1_*LOC_language_standard']
rois_to_average = ['LH_IFGorb','LH_IFG','LH_MFG','LH_AntTemp','LH_PostTemp']
plot_experiments_together_average_rois(result_versionsL,
                                       experiments,
                                       conditions,
                                       colors,
                                       title,
                                       no_outliers=False,
                                       set_ylim=False,
                                       rois_to_average=rois_to_average,
                                       roi_group_name='LH_lang',
                                       include_scatter=False)
# Out:
# mROI_0.1_*LOC_language_standard:
# --------------------------------
# EventsRev/data/mROI_0.1_EventsRevEFFECT_langLOC_language_standard.csv
# ROI 1: LH_IFGorb
# ROI 2: LH_IFG
# ROI 3: LH_MFG
# ROI 4: LH_AntTemp
# ROI 5: LH_PostTemp
#   Number of subjects (by condition):  [19. 19. 19. 19.]
# EventsOrig/data/mROI_0.1_EventsOrigEFFECT_langLOC_language_standard.csv
# ROI 1: LH_IFGorb
# ROI 2: LH_IFG
# ROI 3: LH_MFG
# ROI 4: LH_AntTemp
# ROI 5: LH_PostTemp
#   Number of subjects (by condition):  [12. 12. 12. 12.]
# events2move/data/mROI_0.1_events2moveEFFECT_langLOC_language_standard.csv
# ROI 1: LH_IFGorb
# ROI 2: LH_IFG
# ROI 3: LH_MFG
# ROI 4: LH_AntTemp
# ROI 5: LH_PostTemp
#   Number of subjects (by condition):  [14. 14. 14. 14.]

# %%
# all data points, NO scatter plot, TRIMMED y-axes limits (for GSS_percentile-whole-brain_0.1_0.1 parcels)
result_versions = ['mROI_0.1_*LOC_GSS_percentile-whole-brain_0.1_0.1']
ylims = [
    [-0.35,0.75], # by ROIs
    [-0.25,1],
    [-0.25,1.25],
    [-0.25,1.75]
]
plot_experiments_together(result_versions,experiments,conditions,colors,title,no_outliers=False,set_ylim=True,ylim=ylims,include_scatter=False)
# Out:
# mROI_0.1_*LOC_GSS_percentile-whole-brain_0.1_0.1:
# -------------------------------------------------
# ROI 1: Right_CrusII_VIIb
# langloc/data/mROI_0.1_langLOC_langEFFECT_GSS_percentile-whole-brain_0.1_0.1.csv
#   Number of subjects (by condition):  [754. 754.]
# ArticLoc/data/mROI_0.1_ArticLocEFFECT_langLOC_GSS_percentile-whole-brain_0.1_0.1.csv
#   Number of subjects (by condition):  [33. 33.]
# ProdLoc/data/mROI_0.1_ProdEFFECT_langLOC_GSS_percentile-whole-brain_0.1_0.1.csv
#   Number of subjects (by condition):  [27.]
# Math_2015onward_AliceLocalizer/data/mROI_0.1_Math2015EFFECT_langLOC_GSS_percentile-whole-brain_0.1_0.1.csv
#   Number of subjects (by condition):  [75. 75.]
# MDloc_atlas/data/mROI_0.1_MDatlasEFFECT_langLOC_GSS_percentile-whole-brain_0.1_0.1.csv
#   Number of subjects (by condition):  [640. 640.]
# DigSpan/data/mROI_0.1_DigSpanEFFECT_langLOC_GSS_percentile-whole-brain_0.1_0.1.csv
#   Number of subjects (by condition):  [19. 19.]
# ...

# %%
# all data points, WITH scatter plot
plot_experiments_together(result_versions,experiments,conditions,colors,title,no_outliers=False,set_ylim=False)
# Out:
# mROI_0.1_*LOC_GSS_percentile-ROI-level_0.2_0.1:
# -----------------------------------------------
# ROI 1: Right_CrusII_VIIb_VIIIa
# EventsRev/data/mROI_0.1_EventsRevEFFECT_langLOC_GSS_percentile-ROI-level_0.2_0.1.csv
#   Number of subjects (by condition):  [19. 19. 19. 19.]
# EventsOrig/data/mROI_0.1_EventsOrigEFFECT_langLOC_GSS_percentile-ROI-level_0.2_0.1.csv
#   Number of subjects (by condition):  [12. 12. 12. 12.]
# events2move/data/mROI_0.1_events2moveEFFECT_langLOC_GSS_percentile-ROI-level_0.2_0.1.csv
#   Number of subjects (by condition):  [14. 14. 14. 14.]
# ROI 2: Right_VI_CrusI_CrusII_Dentate
# EventsRev/data/mROI_0.1_EventsRevEFFECT_langLOC_GSS_percentile-ROI-level_0.2_0.1.csv
#   Number of subjects (by condition):  [19. 19. 19. 19.]
# EventsOrig/data/mROI_0.1_EventsOrigEFFECT_langLOC_GSS_percentile-ROI-level_0.2_0.1.csv
#   Number of subjects (by condition):  [12. 12. 12. 12.]
# events2move/data/mROI_0.1_events2moveEFFECT_langLOC_GSS_percentile-ROI-level_0.2_0.1.csv
# ...

# %%
# all data points, WITH scatter plot, averaged over LH lang regions
result_versionsL = ['mROI_0.1_*LOC_language_standard']
rois_to_average = ['LH_IFGorb','LH_IFG','LH_MFG','LH_AntTemp','LH_PostTemp']
plot_experiments_together_average_rois(result_versionsL,
                                       experiments,
                                       conditions,
                                       colors,
                                       title,
                                       no_outliers=False,
                                       set_ylim=False,
                                       rois_to_average=rois_to_average,
                                       roi_group_name='LH_lang')
# Out:
# mROI_0.1_*LOC_language_standard:
# --------------------------------
# EventsRev/data/mROI_0.1_EventsRevEFFECT_langLOC_language_standard.csv
# ROI 1: LH_IFGorb
# ROI 2: LH_IFG
# ROI 3: LH_MFG
# ROI 4: LH_AntTemp
# ROI 5: LH_PostTemp
#   Number of subjects (by condition):  [19. 19. 19. 19.]
# EventsOrig/data/mROI_0.1_EventsOrigEFFECT_langLOC_language_standard.csv
# ROI 1: LH_IFGorb
# ROI 2: LH_IFG
# ROI 3: LH_MFG
# ROI 4: LH_AntTemp
# ROI 5: LH_PostTemp
#   Number of subjects (by condition):  [12. 12. 12. 12.]
# events2move/data/mROI_0.1_events2moveEFFECT_langLOC_language_standard.csv
# ROI 1: LH_IFGorb
# ROI 2: LH_IFG
# ROI 3: LH_MFG
# ROI 4: LH_AntTemp
# ROI 5: LH_PostTemp
#   Number of subjects (by condition):  [14. 14. 14. 14.]

# %%
# all data points, WITH scatter plot, TRIMMED y-axes limits (for GSS_percentile-whole-brain_0.1_0.1 parcels)
result_versions = ['mROI_0.1_*LOC_GSS_percentile-whole-brain_0.1_0.1']
ylims = [
    [-2,2.5], # by ROIs
    [-2.2,5.5],
    [-1.5,4],
    [-2.8,6]
]
plot_experiments_together(result_versions,experiments,conditions,colors,title,no_outliers=False,set_ylim=True,ylim=ylims)
# Out:
# mROI_0.1_*LOC_GSS_percentile-whole-brain_0.1_0.1:
# -------------------------------------------------
# ROI 1: Right_CrusII_VIIb
# langloc/data/mROI_0.1_langLOC_langEFFECT_GSS_percentile-whole-brain_0.1_0.1.csv
#   Number of subjects (by condition):  [754. 754.]
# ArticLoc/data/mROI_0.1_ArticLocEFFECT_langLOC_GSS_percentile-whole-brain_0.1_0.1.csv
#   Number of subjects (by condition):  [33. 33.]
# Math_2015onward_AliceLocalizer/data/mROI_0.1_Math2015EFFECT_langLOC_GSS_percentile-whole-brain_0.1_0.1.csv
#   Number of subjects (by condition):  [75. 75.]
# MDloc_atlas/data/mROI_0.1_MDatlasEFFECT_langLOC_GSS_percentile-whole-brain_0.1_0.1.csv
#   Number of subjects (by condition):  [640. 640.]
# DigSpan/data/mROI_0.1_DigSpanEFFECT_langLOC_GSS_percentile-whole-brain_0.1_0.1.csv
#   Number of subjects (by condition):  [19. 19.]
# MSIT/data/mROI_0.1_MSITEFFECT_langLOC_GSS_percentile-whole-brain_0.1_0.1.csv
#   Number of subjects (by condition):  [15. 15.]
# ...

# %% [markdown]
# ## Figure S10: all SWJN experiments separately (n=3)

# %%
title = 'SWJN_ALL_SFIGURE'
result_versions = [
    'mROI_0.1_*LOC_GSS_percentile-ROI-level_0.2_0.1',
    'mROI_0.2_*LOC_GSS_percentile-ROI-level_0.2_0.1',
    'mROI_0.1_*LOC_GSS_percentile-whole-brain_0.1_0.1',
    'mROI_0.2_*LOC_GSS_percentile-whole-brain_0.1_0.1',
    'mROI_0.1_*LOC_language_GSS_percentile-whole-brain_0.1_0.1',
    'mROI_0.2_*LOC_language_GSS_percentile-whole-brain_0.1_0.1',
    'mROI_0.1_*LOC_language_standard',
    'mROI_0.2_*LOC_language_standard',
    'mROI_0.1_*LOC_symmetrical_GSS_percentile-whole-brain_0.1_0.1',
    'mROI_0.2_*LOC_symmetrical_GSS_percentile-whole-brain_0.1_0.1'
]
experiments = [
    'SWJNV2',
    'SWJN_deluxe',
    'Nlength_con2'
]
conditions = [
    ['S','W','J','N'],
    ['S','W','J','N'],
    ['S','W','J','N']
]
colors = [
    np.array([[0.15,0.15,0.15],
               [0.35,0.35,0.35],
               [0.55,0.55,0.55],
               [0.75,0.75,0.75]]),
    np.array([[0.15,0.15,0.15],
               [0.35,0.35,0.35],
               [0.55,0.55,0.55],
               [0.75,0.75,0.75]]),
    np.array([[0.15,0.15,0.15],
               [0.35,0.35,0.35],
               [0.55,0.55,0.55],
               [0.75,0.75,0.75]])
]

# %%
# all data points, NO scatter plot
test = plot_experiments_together(result_versions,experiments,conditions,colors,title,no_outliers=False,set_ylim=False,include_scatter=False)
# Out:
# mROI_0.1_*LOC_GSS_percentile-ROI-level_0.2_0.1:
# -----------------------------------------------
# ROI 1: Right_CrusII_VIIb_VIIIa
# SWJNV2/data/mROI_0.1_SWJNEFFECT_langLOC_GSS_percentile-ROI-level_0.2_0.1.csv
#   Number of subjects (by condition):  [13. 13. 13. 13.]
# SWJN_deluxe/data/mROI_0.1_SWJNDeluxeEFFECT_langLOC_GSS_percentile-ROI-level_0.2_0.1.csv
#   Number of subjects (by condition):  [22. 22. 22. 22.]
# Nlength_con2/data/mROI_0.1_NlengthEFFECT_langLOC_GSS_percentile-ROI-level_0.2_0.1.csv
#   Number of subjects (by condition):  [36. 36. 36. 36.]
# ROI 2: Right_VI_CrusI_CrusII_Dentate
# SWJNV2/data/mROI_0.1_SWJNEFFECT_langLOC_GSS_percentile-ROI-level_0.2_0.1.csv
#   Number of subjects (by condition):  [13. 13. 13. 13.]
# SWJN_deluxe/data/mROI_0.1_SWJNDeluxeEFFECT_langLOC_GSS_percentile-ROI-level_0.2_0.1.csv
#   Number of subjects (by condition):  [22. 22. 22. 22.]
# Nlength_con2/data/mROI_0.1_NlengthEFFECT_langLOC_GSS_percentile-ROI-level_0.2_0.1.csv
# ...

# %%
# all data points, NO scatter plot, averaged over LH lang regions
result_versionsL = ['mROI_0.1_*LOC_language_standard']
rois_to_average = ['LH_IFGorb','LH_IFG','LH_MFG','LH_AntTemp','LH_PostTemp']
plot_experiments_together_average_rois(result_versionsL,
                                       experiments,
                                       conditions,
                                       colors,
                                       title,
                                       no_outliers=False,
                                       set_ylim=False,
                                       rois_to_average=rois_to_average,
                                       roi_group_name='LH_lang',
                                       include_scatter=False)
# Out:
# mROI_0.1_*LOC_language_standard:
# --------------------------------
# SWJNV2/data/mROI_0.1_SWJNEFFECT_langLOC_language_standard.csv
# ROI 1: LH_IFGorb
# ROI 2: LH_IFG
# ROI 3: LH_MFG
# ROI 4: LH_AntTemp
# ROI 5: LH_PostTemp
#   Number of subjects (by condition):  [13. 13. 13. 13.]
# SWJN_deluxe/data/mROI_0.1_SWJNDeluxeEFFECT_langLOC_language_standard.csv
# ROI 1: LH_IFGorb
# ROI 2: LH_IFG
# ROI 3: LH_MFG
# ROI 4: LH_AntTemp
# ROI 5: LH_PostTemp
#   Number of subjects (by condition):  [22. 22. 22. 22.]
# Nlength_con2/data/mROI_0.1_NlengthEFFECT_langLOC_language_standard.csv
# ROI 1: LH_IFGorb
# ROI 2: LH_IFG
# ROI 3: LH_MFG
# ROI 4: LH_AntTemp
# ROI 5: LH_PostTemp
#   Number of subjects (by condition):  [36. 36. 36. 36.]

# %%
# all data points, NO scatter plot, TRIMMED y-axes limits (for GSS_percentile-whole-brain_0.1_0.1 parcels)
result_versions = ['mROI_0.1_*LOC_GSS_percentile-whole-brain_0.1_0.1']
ylims = [
    [-0.35,0.75], # by ROIs
    [-0.25,1],
    [-0.25,1.25],
    [-0.25,1.75]
]
plot_experiments_together(result_versions,experiments,conditions,colors,title,no_outliers=False,set_ylim=True,ylim=ylims,include_scatter=False)
# Out:
# mROI_0.1_*LOC_GSS_percentile-whole-brain_0.1_0.1:
# -------------------------------------------------
# ROI 1: Right_CrusII_VIIb
# langloc/data/mROI_0.1_langLOC_langEFFECT_GSS_percentile-whole-brain_0.1_0.1.csv
#   Number of subjects (by condition):  [754. 754.]
# ArticLoc/data/mROI_0.1_ArticLocEFFECT_langLOC_GSS_percentile-whole-brain_0.1_0.1.csv
#   Number of subjects (by condition):  [33. 33.]
# ProdLoc/data/mROI_0.1_ProdEFFECT_langLOC_GSS_percentile-whole-brain_0.1_0.1.csv
#   Number of subjects (by condition):  [27.]
# Math_2015onward_AliceLocalizer/data/mROI_0.1_Math2015EFFECT_langLOC_GSS_percentile-whole-brain_0.1_0.1.csv
#   Number of subjects (by condition):  [75. 75.]
# MDloc_atlas/data/mROI_0.1_MDatlasEFFECT_langLOC_GSS_percentile-whole-brain_0.1_0.1.csv
#   Number of subjects (by condition):  [640. 640.]
# DigSpan/data/mROI_0.1_DigSpanEFFECT_langLOC_GSS_percentile-whole-brain_0.1_0.1.csv
#   Number of subjects (by condition):  [19. 19.]
# ...

# %%
# all data points, WITH scatter plot
plot_experiments_together(result_versions,experiments,conditions,colors,title,no_outliers=False,set_ylim=False)
# Out:
# mROI_0.1_*LOC_GSS_percentile-ROI-level_0.2_0.1:
# -----------------------------------------------
# ROI 1: Right_CrusII_VIIb_VIIIa
# SWJNV2/data/mROI_0.1_SWJNEFFECT_langLOC_GSS_percentile-ROI-level_0.2_0.1.csv
#   Number of subjects (by condition):  [13. 13. 13. 13.]
# SWJN_deluxe/data/mROI_0.1_SWJNDeluxeEFFECT_langLOC_GSS_percentile-ROI-level_0.2_0.1.csv
#   Number of subjects (by condition):  [22. 22. 22. 22.]
# Nlength_con2/data/mROI_0.1_NlengthEFFECT_langLOC_GSS_percentile-ROI-level_0.2_0.1.csv
#   Number of subjects (by condition):  [36. 36. 36. 36.]
# ROI 2: Right_VI_CrusI_CrusII_Dentate
# SWJNV2/data/mROI_0.1_SWJNEFFECT_langLOC_GSS_percentile-ROI-level_0.2_0.1.csv
#   Number of subjects (by condition):  [13. 13. 13. 13.]
# SWJN_deluxe/data/mROI_0.1_SWJNDeluxeEFFECT_langLOC_GSS_percentile-ROI-level_0.2_0.1.csv
#   Number of subjects (by condition):  [22. 22. 22. 22.]
# Nlength_con2/data/mROI_0.1_NlengthEFFECT_langLOC_GSS_percentile-ROI-level_0.2_0.1.csv
# ...

# %%
# all data points, WITH scatter plot, averaged over LH lang regions
result_versionsL = ['mROI_0.1_*LOC_language_standard']
rois_to_average = ['LH_IFGorb','LH_IFG','LH_MFG','LH_AntTemp','LH_PostTemp']
plot_experiments_together_average_rois(result_versionsL,
                                       experiments,
                                       conditions,
                                       colors,
                                       title,
                                       no_outliers=False,
                                       set_ylim=False,
                                       rois_to_average=rois_to_average,
                                       roi_group_name='LH_lang')
# Out:
# mROI_0.1_*LOC_language_standard:
# --------------------------------
# SWJNV2/data/mROI_0.1_SWJNEFFECT_langLOC_language_standard.csv
# ROI 1: LH_IFGorb
# ROI 2: LH_IFG
# ROI 3: LH_MFG
# ROI 4: LH_AntTemp
# ROI 5: LH_PostTemp
#   Number of subjects (by condition):  [13. 13. 13. 13.]
# SWJN_deluxe/data/mROI_0.1_SWJNDeluxeEFFECT_langLOC_language_standard.csv
# ROI 1: LH_IFGorb
# ROI 2: LH_IFG
# ROI 3: LH_MFG
# ROI 4: LH_AntTemp
# ROI 5: LH_PostTemp
#   Number of subjects (by condition):  [22. 22. 22. 22.]
# Nlength_con2/data/mROI_0.1_NlengthEFFECT_langLOC_language_standard.csv
# ROI 1: LH_IFGorb
# ROI 2: LH_IFG
# ROI 3: LH_MFG
# ROI 4: LH_AntTemp
# ROI 5: LH_PostTemp
#   Number of subjects (by condition):  [36. 36. 36. 36.]

# %%
# all data points, WITH scatter plot, TRIMMED y-axes limits (for GSS_percentile-whole-brain_0.1_0.1 parcels)
result_versions = ['mROI_0.1_*LOC_GSS_percentile-whole-brain_0.1_0.1']
ylims = [
    [-2,2.5], # by ROIs
    [-2.2,5.5],
    [-1.5,4],
    [-2.8,6]
]
plot_experiments_together(result_versions,experiments,conditions,colors,title,no_outliers=False,set_ylim=True,ylim=ylims)
# Out:
# mROI_0.1_*LOC_GSS_percentile-whole-brain_0.1_0.1:
# -------------------------------------------------
# ROI 1: Right_CrusII_VIIb
# langloc/data/mROI_0.1_langLOC_langEFFECT_GSS_percentile-whole-brain_0.1_0.1.csv
#   Number of subjects (by condition):  [754. 754.]
# ArticLoc/data/mROI_0.1_ArticLocEFFECT_langLOC_GSS_percentile-whole-brain_0.1_0.1.csv
#   Number of subjects (by condition):  [33. 33.]
# Math_2015onward_AliceLocalizer/data/mROI_0.1_Math2015EFFECT_langLOC_GSS_percentile-whole-brain_0.1_0.1.csv
#   Number of subjects (by condition):  [75. 75.]
# MDloc_atlas/data/mROI_0.1_MDatlasEFFECT_langLOC_GSS_percentile-whole-brain_0.1_0.1.csv
#   Number of subjects (by condition):  [640. 640.]
# DigSpan/data/mROI_0.1_DigSpanEFFECT_langLOC_GSS_percentile-whole-brain_0.1_0.1.csv
#   Number of subjects (by condition):  [19. 19.]
# MSIT/data/mROI_0.1_MSITEFFECT_langLOC_GSS_percentile-whole-brain_0.1_0.1.csv
#   Number of subjects (by condition):  [15. 15.]
# ...
